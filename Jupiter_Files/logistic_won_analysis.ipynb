# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from gspread_pandas import Spread, conf

# %%
config_path = r'C:\Users\USER\Downloads\Emarath_global\service_account.json'
# 3. Define the Sheet URL (Name - EMARATH GLOBAL -DASHBOARD)
sheet_url = "https://docs.google.com/spreadsheets/d/1aXobnCl4QQ-hQ_IWoTPo2ZEo3HM5kNwycwMBJtEDOfc/edit?gid=822921427#gid=822921427"
c = conf.get_config(file_name=config_path)
spread = Spread(sheet_url, config=c)
