# %%
config_path = r'C:\Users\USER\Downloads\Emarath_global\service_account.json'
# 3. Define the Sheet URL (Name - Dispapatch list KSA)
report_sheet_url = "https://docs.google.com/spreadsheets/d/1PqMNtFU0bas_BGYFhIYWojO2petW-TOGxeRB2OWnF08/edit?gid=113745152#gid=113745152"
logistic_sheet_url = "https://docs.google.com/spreadsheets/d/1eo2tY_57lcOTtGOyU5GOz2IQON3b0VsVf8rTsbfT3HM/edit?gid=0#gid=0"

fin_dispatch_list_sheet = "https://docs.google.com/spreadsheets/d/1wTjaEYO8VCVu5eZxEXAb25Ed_7E320EWpi3PSqDTEAQ/edit?gid=0#gid=0"
